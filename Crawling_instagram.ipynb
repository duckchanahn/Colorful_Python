# %%
import time
import getpass
from selenium.webdriver.common.keys import Keys

from selenium import webdriver
 #-*- coding: UTF-8 -*-
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support.ui import Select

from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

import getpass

# %%
chromedriver = './chromedriver.exe' # 크롬 드라이버 경로


options = webdriver.ChromeOptions()
# options.add_argument('headless')    # 실행했을 때 웹 브라우저를 띄우지 않는 headless chrome 옵션 적용
options.add_argument('disable-gpu')    # GPU 사용 안함 --> headless 설정, gpu 사용 안함 : 속도 향상
options.add_argument('lang=ko_KR')    # 언어 설정
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36") # 봇 차단을 막기 위한 우회
driver = webdriver.Chrome(chromedriver, options=options) #  옵션 적용

driver.implicitly_wait(100) # 위 설정을 적용하는 데 시간이 걸리기 때문에 기다려주기 (최대 100초를 기다리되, 중간에 완료되면 바로 넘어감)

user_id = input()
user_passwd = getpass.getpass()

instagram_id_name="username"
instagram_pw_name="password"
instagram_login_btn=".sqdOP.L3NKy.y3zKF     "


search_tagname = "제부도"
search_hashtag_url = "https://www.instagram.com/explore/tags/" + search_tagname
instagram_tags_jebudo = []


login_url = "https://www.instagram.com/accounts/login/"

driver.get(login_url)

instagram_id_form = driver.find_element_by_name(instagram_id_name)
instagram_id_form.send_keys(user_id)
time.sleep(5)

instagram_pw_form = driver.find_element_by_name(instagram_pw_name)
instagram_pw_form.send_keys(user_passwd)
time.sleep(7)

login_ok_button = driver.find_element_by_css_selector(instagram_login_btn)
login_ok_button.click()

after_save_button_xpath = '//*[@id="react-root"]/section/main/div/div/div/div/button'
driver.find_element_by_xpath(after_save_button_xpath).click()
after_alarm_button_xpath = '/html/body/div[1]/div/div[1]/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div/div/div/div[3]/button[2]'
driver.find_element_by_xpath(after_alarm_button_xpath).click()

print("로그인 완료")

driver.get(search_hashtag_url)
# for temp_idx in range(1, 30):
#     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#     time.sleep(5)

print("#여행스타그램 검색 완료")

# post_css = "_aagw"
post_css = "_aabd._aa8k._aanf"

post_list = driver.find_elements_by_class_name(post_css)
print(len(post_list))

tag_css="oajrlxb2.g5ia77u1.qu0x051f.esr5mh6w.e9989ue4.r7d6kgcz.rq0escxv.nhd2j8a9.nc684nl6.p7hjln8o.kvgmc6g5.cxmmr5t8.oygrvhab.hcukyx3x.jb3vyjys.rz4wbd8a.qt6c0cv9.a8nywdso.i1ao9s8h.esuyzwwr.f1sip0of.lzcic4wl._aa9_._a6hd"


post_url_list = []

    
# li는 여러개이므로 for문으로 루프
for post in post_list:
#     print("post : ", post)
#     print("post.text : ", post.text)
    aTag = post.find_element_by_tag_name('a')
    href = aTag.get_attribute('href')
#     print(href)
    post_url_list.append(href)
    
#     driver.get(str(href))
    
#     data = driver.find_element_by_css_selector(tag_css) # C7I1f X7jCj
#     tag_raw = data.text
#     tags = re.findall('#[A-Za-z0-9가-힣]+', tag_raw) 
#     tag = ''.join(tags).replace("#"," ") # "#" 제거

#     tag_data = tag.split()

#     for tag_one in tag_data:
#         instagram_tags.append(tag_one)

print(len(post_url_list))
for post_url in post_url_list:
    driver.get(str(post_url))
    
#     elem = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.CLASS_NAME, tag_css)))
#     print("elem : ", elem.text)
#     if(elem):
    try:
        datas = driver.find_elements_by_class_name(tag_css) # C7I1f X7jCj

        for data in datas:
            print("data.text", data.text)
            instagram_tags_jebudo.append(data.text)
    except:
        print("태그 없는 듯 : ", post_url)
    
   
    
    

#     getHashTag(href, driver)


for temp in instagram_tags_jebudo:
    print(temp)
# Out:
# ssaanngg___
# ········
# 로그인 완료
# #여행스타그램 검색 완료
# 21
# 21
# data.text #여행
# data.text #제부도
# data.text #부부여행
# data.text #아들
# data.text #개딸은
# data.text #집에
# data.text #여행스타그램
# data.text #먹스타그램
# data.text #아줌마
# data.text #40대아줌마
# data.text #주부스타그램
# data.text #고딩맘
# data.text #개딸맘
# data.text #먹스타그램
# data.text #회
# data.text #뽀사버린다
# data.text #숯향기
# data.text #푸세이돈_화성
# data.text #제부도맛집
# data.text #제부도고깃집
# data.text #제부도전곡항맛집
# data.text #전곡항맛집
# data.text #제부도
# data.text #제부도여행
# data.text #전곡항
# data.text #전곡항여행
# data.text #숯향기
# data.text #광평리맛집
# data.text #광평리
# data.text #우대갈비맛집
# data.text #화성맛집
# data.text #우대갈비
# data.text #숯향기
# data.text #푸돌핀_화성
# data.text #숯향기
# data.text #맛포트_화성
# data.text #제부도
# data.text #제부도맛집
# data.text #제부도데이트코스
# data.text #제부도맛집추천
# data.text #제부도간장게장
# data.text #제부도근처맛집
# data.text #탄도항
# data.text #제부도
# data.text #석투어🗺
# data.text #여행
# data.text #여행스타그램
# data.text #여행에미치다
# data.text #여행자
# data.text #드라이브
# data.text #바다여행
# data.text #바다
# data.text #국내여행
# data.text #제부도맛집
# data.text #여행맛집
# data.text #맛집여행
# data.text #여행자
# data.text #일상
# data.text #travel
# data.text #travelgram
# data.text #insta
# data.text #instagram
# data.text #likeforlikes
# data.text #daily
# data.text #경기도
# data.text #화성
# data.text #제부도
# data.text #우리들의초여름
# data.text #경기도여행
# data.text #여행에미치다
# data.text #캐논코리아
# data.text #캐논이미지스토밍
# data.text #어디까지가봤니
# data.text #사진에미치다
# data.text #풍경스타그램
# data.text #대한민국구석구석
# data.text #korealandscape
# data.text #TeamLongExposure
# data.text #eosR5
# data.text #제부도찐맛집
# data.text #제부도맛집
# data.text #제부도해장짬뽕
# data.text #제부도물때시간표
# data.text #제부도가볼만한곳
# data.text #제부도맛집추천
# data.text #제부도맛집베스트
# data.text #제부도데이트
# data.text #제부도
# data.text #제부도
# data.text #제부도데이트코스
# data.text #제부도간장게장
# data.text #제부도맛집추천
# data.text #제부도맛집
# data.text #제부도근처맛집
# data.text #탄도항
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text #제부도
# data.text #일몰
# data.text #갯벌체험
# data.text #제부도
# data.text #밀짚모자
# data.text #해적
# data.text #수염
# data.text #제부도
# data.text #제부도빨간등대
# data.text #갈매기
# data.text #새우깡주기
# data.text #무섭지않아요
# data.text #돌하르방
# data.text #제주
# data.text #허영만식객맛집
# data.text #생선찜맛집
# data.text #전곡항마리나
# data.text #구봉도
# data.text #제부도
# data.text #여행
# data.text #당일치기
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text
# data.text #전곡항
# data.text #요트투어
# data.text #낭만선셋
# data.text #노을하늘
# data.text #제이스키
# data.text #프라이빗
# data.text #화성가볼만한곳
# data.text #경기도가볼만한곳
# data.text #제부도
# data.text #제부도
# data.text #제부도해상케이블카
# data.text #여행스타그램
# data.text #당일치기
# data.text #덥다☀️
# data.text #7살딸
# data.text #주말
# data.text #제부도
# data.text #친정찬스
# data.text #갯벌사랑
# data.text #책사랑
# data.text #물놀이패스
# data.text #망둥어
# data.text #새우
# data.text #밤게
# data.text #칠게
# data.text #갑오징어뼈
# data.text #해삼비슷한거
# data.text #오늘손맛이최고네👍
# data.text #제부도
# data.text #서해랑케이블카
# #여행
# #제부도
# #부부여행
# #아들
# #개딸은
# #집에
# #여행스타그램
# #먹스타그램
# #아줌마
# #40대아줌마
# #주부스타그램
# #고딩맘
# #개딸맘
# #먹스타그램
# #회
# #뽀사버린다
# #숯향기
# #푸세이돈_화성
# #제부도맛집
# #제부도고깃집
# #제부도전곡항맛집
# #전곡항맛집
# #제부도
# #제부도여행
# #전곡항
# #전곡항여행
# #숯향기
# #광평리맛집
# #광평리
# #우대갈비맛집
# #화성맛집
# #우대갈비
# #숯향기
# #푸돌핀_화성
# #숯향기
# #맛포트_화성
# #제부도
# #제부도맛집
# #제부도데이트코스
# #제부도맛집추천
# #제부도간장게장
# #제부도근처맛집
# #탄도항
# #제부도
# #석투어🗺
# #여행
# #여행스타그램
# #여행에미치다
# #여행자
# #드라이브
# #바다여행
# #바다
# #국내여행
# #제부도맛집
# #여행맛집
# #맛집여행
# #여행자
# #일상
# #travel
# #travelgram
# #insta
# #instagram
# #likeforlikes
# #daily
# #경기도
# #화성
# #제부도
# #우리들의초여름
# #경기도여행
# #여행에미치다
# #캐논코리아
# #캐논이미지스토밍
# #어디까지가봤니
# #사진에미치다
# #풍경스타그램
# #대한민국구석구석
# #korealandscape
# #TeamLongExposure
# #eosR5
# #제부도찐맛집
# #제부도맛집
# #제부도해장짬뽕
# #제부도물때시간표
# #제부도가볼만한곳
# #제부도맛집추천
# #제부도맛집베스트
# #제부도데이트
# #제부도
# #제부도
# #제부도데이트코스
# #제부도간장게장
# #제부도맛집추천
# #제부도맛집
# #제부도근처맛집
# #탄도항
#
#
#
#
#
#
#
#
#
#
# #제부도
# #일몰
# #갯벌체험
# #제부도
# #밀짚모자
# #해적
# #수염
# #제부도
# #제부도빨간등대
# #갈매기
# #새우깡주기
# #무섭지않아요
# #돌하르방
# #제주
# #허영만식객맛집
# #생선찜맛집
# #전곡항마리나
# #구봉도
# #제부도
# #여행
# #당일치기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# #전곡항
# #요트투어
# #낭만선셋
# #노을하늘
# #제이스키
# #프라이빗
# #화성가볼만한곳
# #경기도가볼만한곳
# #제부도
# #제부도
# #제부도해상케이블카
# #여행스타그램
# #당일치기
# #덥다☀️
# #7살딸
# #주말
# #제부도
# #친정찬스
# #갯벌사랑
# #책사랑
# #물놀이패스
# #망둥어
# #새우
# #밤게
# #칠게
# #갑오징어뼈
# #해삼비슷한거
# #오늘손맛이최고네👍
# #제부도
# #서해랑케이블카

# %%
instagram_tags_tourstagram  # #여행스타그램
instagram_tags_koreatour # #국내여행
# Out:
# 788

# %%
for temp in instagram_tags_jebudo:
    print(temp)
# Out:
# #여행
# #제부도
# #부부여행
# #아들
# #개딸은
# #집에
# #여행스타그램
# #먹스타그램
# #아줌마
# #40대아줌마
# #주부스타그램
# #고딩맘
# #개딸맘
# #먹스타그램
# #회
# #뽀사버린다
# #숯향기
# #푸세이돈_화성
# #제부도맛집
# #제부도고깃집
# #제부도전곡항맛집
# #전곡항맛집
# #제부도
# #제부도여행
# #전곡항
# #전곡항여행
# #숯향기
# #광평리맛집
# #광평리
# #우대갈비맛집
# #화성맛집
# #우대갈비
# #숯향기
# #푸돌핀_화성
# #숯향기
# #맛포트_화성
# #제부도
# #제부도맛집
# #제부도데이트코스
# #제부도맛집추천
# #제부도간장게장
# #제부도근처맛집
# #탄도항
# #제부도
# #석투어🗺
# #여행
# #여행스타그램
# #여행에미치다
# #여행자
# #드라이브
# #바다여행
# #바다
# #국내여행
# #제부도맛집
# #여행맛집
# #맛집여행
# #여행자
# #일상
# #travel
# #travelgram
# #insta
# #instagram
# #likeforlikes
# #daily
# #경기도
# #화성
# #제부도
# #우리들의초여름
# #경기도여행
# #여행에미치다
# #캐논코리아
# #캐논이미지스토밍
# #어디까지가봤니
# #사진에미치다
# #풍경스타그램
# #대한민국구석구석
# #korealandscape
# #TeamLongExposure
# #eosR5
# #제부도찐맛집
# #제부도맛집
# #제부도해장짬뽕
# #제부도물때시간표
# #제부도가볼만한곳
# #제부도맛집추천
# #제부도맛집베스트
# #제부도데이트
# #제부도
# #제부도
# #제부도데이트코스
# #제부도간장게장
# #제부도맛집추천
# #제부도맛집
# #제부도근처맛집
# #탄도항
#
#
#
#
#
#
#
#
#
#
# #제부도
# #일몰
# #갯벌체험
# #제부도
# #밀짚모자
# #해적
# #수염
# #제부도
# #제부도빨간등대
# #갈매기
# #새우깡주기
# #무섭지않아요
# #돌하르방
# #제주
# #허영만식객맛집
# #생선찜맛집
# #전곡항마리나
# #구봉도
# #제부도
# #여행
# #당일치기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# #전곡항
# #요트투어
# #낭만선셋
# #노을하늘
# #제이스키
# #프라이빗
# #화성가볼만한곳
# #경기도가볼만한곳
# #제부도
# #제부도
# #제부도해상케이블카
# #여행스타그램
# #당일치기
# #덥다☀️
# #7살딸
# #주말
# #제부도
# #친정찬스
# #갯벌사랑
# #책사랑
# #물놀이패스
# #망둥어
# #새우
# #밤게
# #칠게
# #갑오징어뼈
# #해삼비슷한거
# #오늘손맛이최고네👍
# #제부도
# #서해랑케이블카

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame.from_records(instagram_tags_tourstagram)
df.to_excel('instagram_tags_tourstagram.xlsx')

df = pd.DataFrame.from_records(instagram_tags_koreatour)
df.to_excel('instagram_tags_koreatour.xlsx')

# %%
import csv

with open("instagram_tags_tourstagram.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(instagram_tags_tourstagram)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-8-e5f4ff46f811> in <module>
#       3 with open("instagram_tags_tourstagram.csv", 'w') as file:
#       4   writer = csv.writer(file)
# ----> 5   writer.writerow(instagram_tags_tourstagram)
#
# UnicodeEncodeError: 'cp949' codec can't encode character '\U0001f1f9' in position 44: illegal multibyte sequence

# %%
import csv

with open("instagram_tags_koreatour.csv", 'w') as file:
  writer = csv.writer(file)
  writer.writerow(instagram_tags_koreatour)
